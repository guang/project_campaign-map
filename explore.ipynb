# %%
"""     @author:        Guang Yang
        @mktime:        2014/07/17
        @description:   Preprocess raw .csv data into workable form in DataFrame
"""
import slugify
import folium
import geopy
import copy
import time
import pandas as pd
import numpy as np
from pandas import Series, DataFrame # NOQA
from geopy.geocoders import GoogleV3


csv_file = '/Users/guangyang/Work/project_campaign-map/data/final.csv'

raw_spins_df = pd.read_csv(csv_file)


def all_action(df, cols):
    """ finds all possible action taken by the stations
    
    Args:
        df: the dataframe to look
        cols: column names under which to search
    
    Returns:
        action_list: an ndarray of all possible actions
    
    """
    action_list = []
    for i in cols:
        action_list = np.union1d(df[i].unique().tolist(), action_list)
    return action_list


def clean_rotation(spin_df):
    """ Converts rotations (light, medium) to number of spins per week
    Light -> 2 spins
    Medium -> 4 spins
    
    
    Args:
        rot_df: the dataframe with rotations in light/medium
    
    Returns:
        spin_df: converted dataframe with spin numbers instead of rotations
        
    """
    spin_df_clean = spin_df.replace('Light', 2) \
                           .replace('Medium', 4) \
                           .replace('Added', 'added') \
                           .replace('in for review', 'in_for_review') \
                           .replace('Library', 'library') \
                           .replace('n/a', 'null')
    return spin_df_clean


def text_to_zero(cleaned_spin_df):
    """ Converts rotation status texts (added, library) to 0.
    
    Args:
        cleaned_spin_df: dataframe with status texts
    
    Returns:
        zeroed_spin_df: dataframe with 0 for status texts
        
    """
    zeroed_spin_df = cleaned_spin_df.replace('added', '0') \
                            .replace('mailed', '0') \
                            .replace('received', '0') \
                            .replace('reviewing', '0') \
                            .replace('in_for_review', '0') \
                            .replace('library', '0') \
                            .replace('null', '0') \
                            .replace('passed', '0')
    return zeroed_spin_df

def df_unique(df):
    """ Find unique values from the dataframe
    
    Args:
        df: pandas dataframe
    
    Returns:
        np.ndarray of unique strings: ['', '', '']
    """
    
    return Series(df.values.ravel()).unique()


def get_lat_long(city, state):
    """ Makes api call to get lat/long from city and state names
    
    Args:
        city: city name (space is fine?)
        state: state name (space is fine?)
    
    Returns:
        tuple of floats: (lat, long)
    
    """
    time.sleep(1)
    geolocator = GoogleV3()
    #geolocator = GoogleV3(api_key=None,
    #                      domain='maps.googleapis.com',
    #                      scheme='https',
    #                      client_id=None,
    #                      secret_key=None)
    address, (latitude, longitude) = geolocator.geocode("{city}, {state}".format(city=city,
                                                                                 state=state))
    return [latitude, longitude]


def add_lat_long(row):
    """ Add latitude and longitude into the dataframe (insert them after states)
    
    Args:
        row: df row from raw without lat/long
    
    Returns:
        row: df row with lat/long
    """
    lat_long = get_lat_long(row['city'], row['state'])
    full_row = pd.concat([row[:3],
                          Series(data=lat_long, index=['latitude', 'longitude']),
                          row[3:]])
    return full_row


def reformat_for_d3(row):
    """ Reformats a df row into a dataframe
    
    Args:
        row: a row from the processed spins_df
        
    Returns:
        dataframe: a dataframe 
    """
    pass

# alias party
DataFrame.unique_values = df_unique


# Notes
# the status goes from mailed -> received -> in_for_review -> reviewing -> added -> (library)

# %%
all_dates = [u'6/9', u'6/16', u'6/23', u'6/30', u'7/7', u'7/14', u'7/21', u'7/28', u'8/4', u'8/11', u'8/18', u'8/25', u'9/1', 
             u'9/8', u'9/15', u'9/22', u'9/29', u'10/6', u'10/13', u'10/20', u'10/27', u'11/3', u'11/10', u'11/17']

# clean up the status during each week
raw_spins_df_clean = copy.copy(raw_spins_df)
raw_spins_df_clean[all_dates] = clean_rotation(raw_spins_df[all_dates])

# add lat/long for each station based on city, state
spins_df = raw_spins_df_clean.apply(func=add_lat_long, axis=1)

# convert status texts to 0's
# raw_spins_df_zeros = copy.copy(raw_spins_df_clean)
# raw_spins_df_zeros[all_dates] = text_to_zero(raw_spins_df_clean[all_dates])
raw_spins_df_zeros = copy.copy(spins_df)
raw_spins_df_zeros[all_dates] = text_to_zero(spins_df[all_dates])

# aggregate data by state
# state_714 = raw_spins_df_zeros[['state', '7/14']].convert_objects(convert_numeric=True)
# temp_state = state_714.groupby(['state']).sum()

# convert to d3 format
# d3_spins_df =

# %%
date804 = raw_spins_df_zeros[['station', 'latitude', 'longitude', '8/4']]
date804.to_json('date804.json')

# %%
raw_spins_df_zeros[['station', 'latitude', 'longitude', '6/16']].to_csv('date609.csv')

# %%
for date in all_dates:
    raw_spins_df_zeros[['station', 'latitude', 'longitude', date]].rename(columns={date: 'count'})\
    .to_csv('date{}.csv'.format(slugify.slugify(date)))

# %%
raw_spins_df_zeros[all_dates].unique_values()
# Out:
# array(['0', '15', '25', '35', '45', '10', '20', '30', '40', '55', '60', 2,
#        4, '7', '8', '9', '2', '3', '6', '12', '14', '16', '18', '4', '28',
#        'passed', '29', '39', '38', '46', '11', '32', '5'], dtype=object)

# %%
# Out:
# CPU times: user 873 ms, sys: 150 ms, total: 1.02 s
# Wall time: 38 s
#        station             city state   latitude   longitude            6/9  \
# 0         EASY       Tuscarawas    OH  40.394789  -81.407058       received
# 1    Indie 104           Covina    CA  34.090009 -117.890340          added
# 2         KACV         Amarillo    TX  35.221997 -101.831297       received
# 3         KALA        Davenport    IA  41.523644  -90.577637       received
# 4         KALW        Sunnyvale    CA  37.368830 -122.036350         mailed
# 5         KALX         Berkeley    CA  37.871593 -122.272747       received
# 6         KAOS          Olympia    WA  47.037874 -122.900695  in_for_review
# 7         KBCS         Bellevue    WA  47.610377 -122.200679         mailed
# 8       KBEACH       Long Beach    CA  33.770050 -118.193740       received
# 9         KBGA         Missoula    MT  46.878718 -113.996586         mailed
# 10        KBHI   Cape Girardeau    MO  37.305884  -89.518148       received
# 11        KBOO         Portland    OR  45.523062 -122.676482         mailed
# 12       KBPK        Fullterton    CA  33.870360 -117.924297       received
# 13        KBSB          Bemidji    MN  47.487536  -94.885849         mailed
# 14        KBUT    Crested Butte    CO  38.869715 -106.987823       received
# 15        KBVR        Corvallis    OR  44.564566 -123.262044       received
# 16        KCFV        St. Louis    MO  38.627003  -90.199404         mailed
# 17        KCHE        Cherokee     IA  42.749641  -95.551543          added
# 18        KCMP          St Paul    MN  44.953703  -93.089958         mailed
# 19        KCOU         Columbia    MO  38.951705  -92.334072       received
# 20        KCPR  San Luis Obispo    CA  35.282752 -120.659616       received
# 21        KCSN       Northridge    CA  34.238125 -118.530123         mailed
# 22        KCSS          Turlock    CA  37.494657 -120.846594         mailed
# 23        KDHX        St. Louis    MO  38.627003  -90.199404      reviewing
# 24        KDNK       Carbondale    CO  39.402205 -107.211163         mailed
# 25        KDUR          Durango    CO  37.275280 -107.880067         mailed
# 26        KDVS            Davis    CA  38.544907 -121.740517         mailed
# 27        KDWG           Dillon    MT  45.216632 -112.638924  in_for_review
# 28        KEOL         LaGrande    OR  45.324577 -118.087719         mailed
# 29        KEUL         Girdwood    AK  60.954325 -149.159898       received
# ..         ...              ...   ...        ...         ...            ...
# 128       WORG             Cope    SC  33.377934  -81.007040          added
# 129       WQXQ     Central City    KY  37.293932  -87.123329       received
# 130       WRAL          Raleigh    NC  35.779590  -78.638179           null
# 131       WRAS          Atlanta    GA  33.748995  -84.387982       received
# 132       WRCT       Pittsburgh    PA  40.440625  -79.995886         mailed
# 133       WREZ       Metropolis    IL  37.151165  -88.731998      reviewing
# 134      WRFL         Lexington    KY  38.040584  -84.503716         mailed
# 135       WRGP            Miami    FL  25.761680  -80.191790       received
# 136       WRIU        Kingston     RI  41.480379  -71.522560         mailed
# 137       WSBF          Clemson    SC  34.683438  -82.837365       received
# 138       WSHC    Shepherdstown    WV  39.430100  -77.804161         mailed
# 139       WSLC          Roanoke    VA  37.270970  -79.941427       received
# 140       WSOE             Elon    NC  36.098276  -79.511543       received
# 141       WTUL      New Orleans    LA  29.951066  -90.071532         mailed
# 142       WUAG       Greensboro    NC  36.072635  -79.791975       received
# 143       WUOG          Athens     GA  33.951935  -83.357567       received
# 144       WUPX        Marquette    MI  46.547582  -87.395595       received
# 145       WUSC         Columbia    SC  34.000710  -81.034814       received
# 146       WUSM      Hattiesburg    MS  31.327119  -89.290339         mailed
# 147       WUTK        Knoxville    TN  35.960638  -83.920739         mailed
# 148       WVFS     Tallahassee     FL  30.438256  -84.280733  in_for_review
# 149       WVMP          Roanoke    VA  37.270970  -79.941427       received
# 150       WVUA       Tuscaloosa    AL  33.209841  -87.569173         mailed
# 151       WVVS         Valdosta    GA  30.832702  -83.278485         mailed
# 152       WWMX        Baltimore    MD  39.290385  -76.612189           null
# 153       WXDU           Durham    NC  35.994033  -78.898619         mailed
# 154       WXYC      Chapel Hill    NC  35.913200  -79.055845         mailed
# 155       WYUL          Malone     NY  44.848660  -74.294898          added
# 156       WZFT        Baltimore    MD  39.290385  -76.612189           null
# 157       WZMB       Greenville    NC  35.612661  -77.366354         mailed
#
#               6/16           6/23           6/30            7/7  \
# 0         received       received       received       received
# 1               10             15             20             25
# 2         received  in_for_review      reviewing          added
# 3    in_for_review      reviewing          added              2
# 4           mailed       received  in_for_review      reviewing
# 5         received  in_for_review      reviewing      reviewing
# 6        reviewing          added              2              2
# 7         received       received  in_for_review      reviewing
# 8    in_for_review      reviewing          added              2
# 9         received       received  in_for_review      reviewing
# 10   in_for_review      reviewing          added              7
# 11        received  in_for_review      reviewing          added
# 12       reviewing          added              2              2
# 13          mailed       received       received  in_for_review
# 14        received  in_for_review      reviewing          added
# 15   in_for_review      reviewing          added              2
# 16        received  in_for_review      reviewing          added
# 17               6              8              8             10
# 18          mailed       received       received  in_for_review
# 19   in_for_review      reviewing          added              2
# 20        received  in_for_review      reviewing          added
# 21        received       received  in_for_review      reviewing
# 22          mailed       received       received  in_for_review
# 23           added        library        library        library
# 24          mailed       received       received  in_for_review
# 25        received       received  in_for_review      reviewing
# 26        received  in_for_review      reviewing          added
# 27       reviewing          added              2              2
# 28        received       received  in_for_review      reviewing
# 29   in_for_review      reviewing          added              2
# ..             ...            ...            ...            ...
# 128              5              5              5              5
# 129       received       received  in_for_review  in_for_review
# 130         mailed         mailed       received       received
# 131       received  in_for_review      reviewing          added
# 132         mailed       received       received  in_for_review
# 133          added              7              7              7
# 134         mailed       received       received  in_for_review
# 135       received  in_for_review      reviewing          added
# 136       received  in_for_review      reviewing          added
# 137  in_for_review      reviewing          added              2
# 138         mailed       received       received  in_for_review
# 139  in_for_review      reviewing          added              2
# 140  in_for_review      reviewing      reviewing          added
# 141       received  in_for_review      reviewing          added
# 142  in_for_review      reviewing      reviewing          added
# 143       received  in_for_review      reviewing      reviewing
# 144       received      reviewing          added              2
# 145  in_for_review      reviewing          added              2
# 146       received       received  in_for_review      reviewing
# 147         mailed       received       received  in_for_review
# 148      reviewing          added              2              2
# 149  in_for_review      reviewing          added              2
# 150       received  in_for_review      reviewing          added
# 151         mailed       received       received  in_for_review
# 152           null           null           null           null
# 153       received       received  in_for_review      reviewing
# 154       received       received  in_for_review      reviewing
# 155              5              5              5             10
# 156           null           null           null           null
# 157         mailed       received       received  in_for_review
#
#                          ...                            9/22       9/29  \
# 0                        ...                              35         45
# 1                        ...                              60         60
# 2                        ...                               4          4
# 3                        ...                               4          4
# 4                        ...                               2          2
# 5                        ...                         library    library
# 6                        ...                               4          4
# 7                        ...                               2          2
# 8                        ...                               4          4
# 9                        ...                               2          2
# 10                       ...                               9          9
# 11                       ...                               2          2
# 12                       ...                               3          3
# 13                       ...                               2          2
# 14                       ...                               4          4
# 15                       ...                               4          4
# 16                       ...                               4          4
# 17                       ...                              18         18
# 18                       ...                               2          2
# 19                       ...                               4          4
# 20                       ...                               2          2
# 21                       ...                               2          2
# 22                       ...                               4          4
# 23                       ...                         library    library
# 24                       ...                         library    library
# 25                       ...                               2          2
# 26                       ...                               4          4
# 27                       ...                               4          4
# 28                       ...                               2          2
# 29                       ...                               4          4
# ..                       ...                             ...        ...
# 128                      ...                              45         45
# 129                      ...                       reviewing  reviewing
# 130                      ...                         library    library
# 131                      ...                               2          2
# 132                      ...                               2          2
# 133                      ...                               9          9
# 134                      ...                               2          2
# 135                      ...                               2          2
# 136                      ...                               4          4
# 137                      ...                               2          2
# 138                      ...                         library    library
# 139                      ...                               2          2
# 140                      ...                         library    library
# 141                      ...                               4          4
# 142                      ...                         library    library
# 143                      ...                               2          2
# 144                      ...                               2          2
# 145                      ...                               4          4
# 146                      ...                               2          2
# 147                      ...                               4          4
# 148                      ...                               4          4
# 149                      ...                               4          4
# 150                      ...                               4          4
# 151                      ...                               2          2
# 152                      ...                            null       null
# 153                      ...                               2          2
# 154                      ...                               2          2
# 155                      ...                              28         28
# 156                      ...                            null       null
# 157                      ...                               2          2
#
#           10/6      10/13      10/20      10/27       11/3      11/10  \
# 0           45         45         45         45         45         45
# 1           60         60         60         60         60         60
# 2            4          4          4          4          4          4
# 3            4          4          4          4          4          4
# 4            2          2          2          2          2          2
# 5      library    library    library    library    library    library
# 6            4          4          4          4          4          4
# 7            2          2          2          2          2          2
# 8            4          4          4          4          4          4
# 9            2          2          2          2          2          2
# 10           9          9          9          9          9          9
# 11           2          2          2          2          2          2
# 12           3          3          3          3          3          3
# 13           2          2          2          2          2          2
# 14           4          4          4          4          4          4
# 15           4          4          4          4          4          4
# 16           4          4          4          4          4          4
# 17          18         20         20         20         20         20
# 18           2          2          2          2          2          2
# 19           4          4          4          4          4          4
# 20           2          2          2          2          2          2
# 21           2          2          2          2          2          2
# 22           4          4          4          4          4          4
# 23     library    library    library    library    library    library
# 24     library    library    library    library    library    library
# 25           2          2          2          2          2          2
# 26           4          4          4          4          4          4
# 27           4          4          4          4          4          4
# 28           2          2          2          2          2          2
# 29           4          4          4          4          4          4
# ..         ...        ...        ...        ...        ...        ...
# 128         45         45         45         45         45         45
# 129  reviewing  reviewing  reviewing  reviewing  reviewing  reviewing
# 130    library    library    library    library    library    library
# 131          2          2          2          2          2          2
# 132          2          2          2          2          2          2
# 133          9          9          9          9          9          9
# 134          2          2          2          2          2          2
# 135          2          2          2          2          2          2
# 136          4          4          4          4          4          4
# 137          2          2          2          2          2          2
# 138    library    library    library    library    library    library
# 139          2          2          2          2          2          2
# 140    library    library    library    library    library    library
# 141          4          4          4          4          4          4
# 142    library    library    library    library    library    library
# 143          2          2          2          2          2          2
# 144          2          2          2          2          2          2
# 145          4          4          4          4          4          4
# 146          2          2          2          2          2          2
# 147          4          4          4          4          4          4
# 148          4          4          4          4          4          4
# 149          4          4          4          4          4          4
# 150          4          4          4          4          4          4
# 151          2          2          2          2          2          2
# 152       null       null       null       null       null       null
# 153          2          2          2          2          2          2
# 154          2          2          2          2          2          2
# 155         28         28         28         28         28         28
# 156       null       null       null       null       null       null
# 157          2          2          2          2          2          2
#
#          11/17                                      comments
# 0           45                                           NaN
# 1           60                                           NaN
# 2            4          Medium Rotation: 3-5 spins per week
# 3            4          Medium Rotation: 3-5 spins per week
# 4            2                                           NaN
# 5      library    Added to music library; available for play
# 6            4                                           NaN
# 7            2                                           NaN
# 8            4          Medium Rotation: 3-5 spins per week
# 9            2                                           NaN
# 10           9                                           NaN
# 11           2           Light Rotation: 1-3 spins per week
# 12           3                                           NaN
# 13           2                                           NaN
# 14           4          Medium Rotation: 3-5 spins per week
# 15           4                          Phone Interview 8/28
# 16           4          Medium Rotation: 3-5 spins per week
# 17          20                                           NaN
# 18           2                                           NaN
# 19           4          Medium Rotation: 3-5 spins per week
# 20           2                                           NaN
# 21           2                                           NaN
# 22           4          Medium Rotation: 3-5 spins per week
# 23     library    Added to music library; available for play
# 24     library    Added to music library; available for play
# 25           2                                           NaN
# 26           4                    Medium Rotation: 3-5 spins
# 27           4                    Medium Rotation: 3-5 spins
# 28           2                                           NaN
# 29           4          Medium Rotation: 3-5 spins per week
# ..         ...                                           ...
# 128         45                                           NaN
# 129  reviewing                                           NaN
# 130    library  Added to music library; approved for airplay
# 131          2                                           NaN
# 132          2                                           NaN
# 133          9                                           NaN
# 134          2                                           NaN
# 135          2                                           NaN
# 136          4                                           NaN
# 137          2           Light Rotation: 1-3 spins per week
# 138    library    Added to music library; available for play
# 139          2           Light Rotation: 1-3 spins per week
# 140    library    Added to music library; available for play
# 141          4                                           NaN
# 142    library    Added to music library; available for play
# 143          2                                           NaN
# 144          2                                           NaN
# 145          4          Medium Rotation: 3-5 spins per week
# 146          2                                           NaN
# 147          4                                           NaN
# 148          4           Medium Rotation: 3-5 spins per week
# 149          4                                           NaN
# 150          4                                           NaN
# 151          2                                           NaN
# 152       null                     submitted to upon request
# 153          2                                           NaN
# 154          2                                           NaN
# 155         28                                           NaN
# 156       null                        looking for hits only
# 157          2                                           NaN
#
# [158 rows x 30 columns]
